# %% [markdown]
# <a href="https://colab.research.google.com/github/nikorose87/MoM-resources/blob/main/Exam_1stTerm2021II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluación escrita
# ## Resistencia de Materiales
# **2021--II**
#
# Se presentan dos puntos relacionados a la temática de carga axial bajo los efectos de cambios a tempreatura y concentradores de esfuerzos. Cada punto vale 2.5 unidades. El procedimiento, de ser correcto, le dará 0.5 unidades por punto.
#
# Éxitos
#
# ### Carga axial por la influencia térmica
#
# El rodillo AB contiene $n$ elementos, cada uno con una distribución homogénea en su sección transversal. El punto A se encuentra fijo, mientras que existe una luz $\delta_0$ cercana al punto B para quedar totalmente apoyada en sus dos secciones. Cada sección del rodillo contiene sus propiedades de longitud $L_i$, su diámetro $d$, y su módulo de elasticidad $E$ está dado por el material. Para el sistema general se brinda el $\delta_0$ [mm] y el $\Delta T$. [°C] Las unidades son metros, milímetros y GPa para $L_i$, $d_i$ y $E_i$, respectivamente.
#
# ![ima1](https://www.dropbox.com/s/ytbfm9v6wgfron9/problem1.png?dl=1)
#
# Cada estudiante tendrá unas condiciones únicas que se muestran en el siguiente dataframe, considere esos datos para resolver las fuerzas de reacción en A y B una vez se cierra el sistema a causa de la expansión térmica. Por otro lado cálcule el esfuerzo normal en cada elemento y su deformación.

# %%
import pandas as pd
import numpy as np

not_lock = False
if not_lock:
    max_elem= 6
    classlist1 = pd.read_excel("MoM 2021 II Asistencia.xlsx")
    num_elements = np.random.choice(np.arange(2,max_elem), 16)
    Delta_T = np.random.choice(np.arange(60,120,10),16) 
    delta_0 = np.random.choice(np.linspace(0.01,5,10),16) 
    classlist1['NumElems'] = num_elements
    classlist1['DeltaT'] = Delta_T
    classlist1['delta_0'] = delta_0
    for i in range(max_elem-1):
        classlist1['L_{}'.format(i)] = np.nan
        classlist1['d_{}'.format(i)] = np.nan
        classlist1['E_{}'.format(i)] = np.nan
    for k,i in enumerate(num_elements):
        for j in range(i):
            classlist1.loc[k,'L_{}'.format(j)] = np.random.rand()
            classlist1.loc[k,'d_{}'.format(j)] = np.random.rand()*50
            classlist1.loc[k,'E_{}'.format(j)] = np.random.choice([73, 200])
    classlist1.to_csv("List1.csv")
else:
    classlist1 = pd.read_csv("List1.csv")
classlist1
# Out:
#     Unnamed: 0           ID                                 Nombre  NumElems  \
# 0            0  30000057972                DÍAZ PÉREZ,DAVID STEVEN         3
# 1            1  30000025188                Florez Huerfano,Brandon         4
# 2            2  30000048970         GARCIA RODRIGUEZ,ANDRES FELIPE         3
# 3            3  30000057750            GRACIA GUERRA,DANIEL FELIPE         3
# 4            4  30000050481          IGLESIAS GARCIA,ANDRES FELIPE         5
# 5            5  30000057155   JARAMILLO GUTIERREZ,FABIAN ALEJANDRO         4
# 6            6  30000048121           PARRA MADRIGAL,JUAN GILBERTO         3
# 7            7  30000043745            PORTILLA HURTADO,JUAN PABLO         4
# 8            8  30000057974               PÉREZ CASTRILLÓN,NICOLÁS         3
# 9            9  30000049983          ROMERO REY,CRISTIAN ALEXANDER         3
# 10          10  30000025180            SALGADO DÍAZ,ALLEN SANTIAGO         5
# 11          11  30000049526              SANCHEZ GALVIS,JUAN DAVID         3
# 12          12  30000050119         SUAREZ FORERO,ANDERSON GIOVANY         5
# 13          13  30000060403           VAQUEN MARQUEZ,DANIEL CAMILO         5
# 14          14  30000047652  VILLAMIL TORRES,JORGE ELIECER ALFREDO         3
# 15          15  30000022180       Vargas Rodriguez,Cristian Camilo         3
#
#     DeltaT   delta_0       L_0        d_0    E_0       L_1  ...    E_1  \
# 0       70  2.782222  0.397461  33.325746   73.0  0.215302  ...   73.0
# 1      100  2.227778  0.902100   9.280554   73.0  0.841067  ...   73.0
# 2       90  3.336667  0.031979  13.794431  200.0  0.473359  ...  200.0
# 3      110  2.227778  0.110383  19.518873   73.0  0.307274  ...   73.0
# 4       60  4.445556  0.720969  41.085693  200.0  0.007378  ...   73.0
# 5      110  2.782222  0.233999   6.346473  200.0  0.522088  ...  200.0
# 6      100  3.891111  0.722280  20.283312  200.0  0.035312  ...   73.0
# 7       60  3.891111  0.141195  28.114374  200.0  0.451894  ...   73.0
# 8      110  3.336667  0.808239  27.017266   73.0  0.299962  ...  200.0
# 9       80  2.227778  0.834159   8.014710  200.0  0.913565  ...   73.0
# 10      70  1.673333  0.058007   9.136366  200.0  0.520802  ...   73.0
# 11      60  3.891111  0.282232   8.235624  200.0  0.797374  ...   73.0
# 12      90  1.118889  0.304567  38.473004   73.0  0.823489  ...   73.0
# 13     110  0.564444  0.129973  31.243987  200.0  0.736744  ...  200.0
# 14      70  4.445556  0.966183  48.733766  200.0  0.923095  ...  200.0
# 15      90  1.118889  0.191311   7.773752  200.0  0.491480  ...  200.0
#
#          L_2        d_2    E_2       L_3        d_3    E_3       L_4  \
# 0   0.591107  21.362048   73.0       NaN        NaN    NaN       NaN
# 1   0.842190  39.399106  200.0  0.880646  39.212634   73.0       NaN
# 2   0.360289  23.985642   73.0       NaN        NaN    NaN       NaN
# 3   0.517515  30.994055   73.0       NaN        NaN    NaN       NaN
# 4   0.797631  41.704219  200.0  0.756737  36.901405   73.0  0.946246
# 5   0.280828  41.652828   73.0  0.212797  45.986523   73.0       NaN
# 6   0.236925  13.371977   73.0       NaN        NaN    NaN       NaN
# 7   0.594184  20.997000   73.0  0.409884  11.875963   73.0       NaN
# 8   0.921190   9.524074   73.0       NaN        NaN    NaN       NaN
# 9   0.635078  20.053819   73.0       NaN        NaN    NaN       NaN
# 10  0.417398  11.767176  200.0  0.248933  21.779259  200.0  0.822517
# 11  0.115373  31.001476  200.0       NaN        NaN    NaN       NaN
# 12  0.238825  29.040875   73.0  0.701444  20.781226   73.0  0.008410
# 13  0.820262  31.516269   73.0  0.828022  17.849749  200.0  0.588401
# 14  0.242763  11.394196  200.0       NaN        NaN    NaN       NaN
# 15  0.460070  41.681182   73.0       NaN        NaN    NaN       NaN
#
#           d_4    E_4
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4    4.144726   73.0
# 5         NaN    NaN
# 6         NaN    NaN
# 7         NaN    NaN
# 8         NaN    NaN
# 9         NaN    NaN
# 10   0.650979  200.0
# 11        NaN    NaN
# 12  32.995702  200.0
# 13  20.993099  200.0
# 14        NaN    NaN
# 15        NaN    NaN
#
# [16 rows x 21 columns]

# %% [markdown]
# ### Concentradores de esfuerzo bajo carga axial
#
# Se presenta la siguiente lámina sometida a una carga $P$ con una reducción de cambio de sección y con un agujero en su centro $x$. Le proveen las siguientes formulaciones para determinar la concentricidad de esfuerzo $K$ tanto para el agujero, así como el cambio de sección.
#
# ![ima2](https://www.dropbox.com/s/vtg0g8x2q3673ey/problem2.png?dl=1)
# ![ima3](https://www.dropbox.com/s/g9nyak3ec8lahgb/hole-stress-concentration.png?dl=1)
# ![ima4](https://www.dropbox.com/s/4hi128zvw1yyqqu/stress-factor.png?dl=1)
#
# Se requiere que usted, como ingeniero, determine:
# 1. El radio $r_f$ en los filetes para el cual ocurre el mismo esfuerzo máximo ($\sigma_{max}$) en los filetes y en el agujero, en otras palabras: $\sigma_{hole} = \sigma_{fillet}$.
# 2. Si el máximo esfuerzo permisible $\sigma_{allow} = 100$MPa, determina la carga $P$ máxima permitida para ese esfuerzo.
#
# Considere $x$ como el último dígito de su código multiplicado por 5, de ser 0 considere $x = 50$mm
